# %%
import pandas as pd

df = pd.read_parquet('data.parquet')
print(df.head())
# Out:
#    txn_id                             reference  client_id  card_id  pos_id  \
# 0       1  56251742-6e8e-42f3-ac40-7ca6ddfe1952       9122    13920   121.0
# 1       2  e4a8de0e-7bf0-455b-a7bb-acc8d8ed1a66       3853     4304   114.0
# 2       4  f8f454cf-9a17-4344-982d-f6f9024eb17c       2216     2196     NaN
# 3       5  332b1d12-36f6-48db-a5a4-b99fd84f8eae       9326     5234     NaN
# 4       6  35c8da4b-7911-498e-a36d-2799ad087970       1056    16011    62.0
#
#    merchant_id  type_id  status_id   amount currency  ...     ip_address  \
# 0          137        1          1    10.56      USD  ...           None
# 1           93        2          2     2.21      USD  ...           None
# 2            9        2          2  3495.50      CAD  ...  140.212.25.51
# 3          170        1          1    16.28      EUR  ...           None
# 4           46        3          1   741.19      USD  ...  223.203.5.109
#
# ...
